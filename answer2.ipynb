# %%
import pandas as pd
first = pd.read_csv("main.csv")
first.tail()
# Out:
#      product_code product_description product_group  sales_date  price  \
# 295          1203         butter-0.25         dairy  2021-11-26   11.9
# 296          1203         butter-0.25         dairy  2021-11-27   11.9
# 297          1203         butter-0.25         dairy  2021-11-28   11.9
# 298          1203         butter-0.25         dairy  2021-11-29   11.9
# 299          1203         butter-0.25         dairy  2021-11-30   11.9
#
#      sales_quantity unit
# 295              31  pcs
# 296              29  pcs
# 297              37  pcs
# 298              34  pcs
# 299              36  pcs

# %%
first.head()
# Out:
#    product_code product_description product_group  sales_date  price  \
# 0          1001              tomato     vegetable  2021-11-01   2.99
# 1          1001              tomato     vegetable  2021-11-02   2.99
# 2          1001              tomato     vegetable  2021-11-03   2.99
# 3          1001              tomato     vegetable  2021-11-04   2.99
# 4          1001              tomato     vegetable  2021-11-05   2.99
#
#    sales_quantity unit
# 0              36   kg
# 1              23   kg
# 2              34   kg
# 3              23   kg
# 4              34   kg

# %%
first.groupby('product_description')['price'].mean()
# Out:
# product_description
# apple           2.077778
# butter-0.25    11.400000
# cucumber        4.532857
# grape           4.400000
# milk-1.5        6.078571
# onion           2.150714
# orange          2.714286
# plum            4.389655
# tomato          3.121034
# yogurt-1        6.693103
# Name: price, dtype: float64

# %%
first["sales_amount"]=first["sales_quantity"].where(first["unit"] !="pcs",first["product_description"].str.split("-",expand=True)[1].astype("float") *\
first["sales_quantity"]
)

# %%
first.tail()
# Out:
#      product_code product_description product_group  sales_date  price  \
# 295          1203         butter-0.25         dairy  2021-11-26   11.9
# 296          1203         butter-0.25         dairy  2021-11-27   11.9
# 297          1203         butter-0.25         dairy  2021-11-28   11.9
# 298          1203         butter-0.25         dairy  2021-11-29   11.9
# 299          1203         butter-0.25         dairy  2021-11-30   11.9
#
#      sales_quantity unit  sales_amount
# 295              31  pcs          7.75
# 296              29  pcs          7.25
# 297              37  pcs          9.25
# 298              34  pcs          8.50
# 299              36  pcs          9.00
